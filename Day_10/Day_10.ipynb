# %%
import pandas as pd

# %%
df=pd.read_csv("general_data.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
df.head(80).describe()
# Out:
#              Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  \
# count  80.000000         80.000000  80.000000           80.0     80.0000
# mean   36.475000          7.825000   2.800000            1.0     40.5000
# std     9.084658          6.929619   1.095445            0.0     23.2379
# min    18.000000          1.000000   1.000000            1.0      1.0000
# 25%    29.750000          2.000000   2.000000            1.0     20.7500
# 50%    36.000000          7.000000   3.000000            1.0     40.5000
# 75%    43.000000         10.000000   4.000000            1.0     60.2500
# max    58.000000         29.000000   5.000000            1.0     80.0000
#
#         JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  80.000000      80.000000            80.00000          80.000000
# mean    1.962500   62541.375000             2.37500          15.275000
# std     1.084339   45599.715571             2.35665           4.003084
# ...

# %% [markdown]
# Null Hypothesis: for sample of 80 employees the mean age is found to be 40

# %%
df.head(35).describe()
# Out:
#              Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  \
# count  35.000000         35.000000  35.000000           35.0   35.000000
# mean   36.914286          7.285714   2.885714            1.0   18.000000
# std     9.444486          6.341142   1.131668            0.0   10.246951
# min    21.000000          1.000000   1.000000            1.0    1.000000
# 25%    29.000000          1.500000   2.000000            1.0    9.500000
# 50%    36.000000          7.000000   3.000000            1.0   18.000000
# 75%    44.500000         10.000000   4.000000            1.0   26.500000
# max    55.000000         28.000000   5.000000            1.0   35.000000
#
#         JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  35.000000      35.000000            35.00000          35.000000
# mean    1.742857   66438.000000             2.20000          14.428571
# std     0.980482   41292.059684             2.25962           3.890303
# ...

# %% [markdown]
# Null Hypothesis: for sample of 35 employees the mean PercentSalaryHike is found to be 10%

# %%
df.head(200).describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeCount  EmployeeID  \
# count  200.000000        200.000000  200.000000          200.0  200.000000
# mean    36.645000          9.170000    2.875000            1.0  100.500000
# std      9.327054          7.943336    0.992117            0.0   57.879185
# min     18.000000          1.000000    1.000000            1.0    1.000000
# 25%     30.000000          2.000000    2.000000            1.0   50.750000
# 50%     36.000000          7.000000    3.000000            1.0  100.500000
# 75%     42.000000         14.000000    4.000000            1.0  150.250000
# max     60.000000         29.000000    5.000000            1.0  200.000000
#
#          JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  200.000000     200.000000          199.000000         200.000000
# mean     2.080000   60749.300000            2.748744          15.600000
# std      1.140219   42443.620204            2.581438           3.968469
# ...

# %% [markdown]
# Null Hypothesis: for sample of 200 employees the mean MonthlyIncome is found to be 50000

# %%
df.head(80).describe()
# Out:
#              Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  \
# count  80.000000         80.000000  80.000000           80.0     80.0000
# mean   36.475000          7.825000   2.800000            1.0     40.5000
# std     9.084658          6.929619   1.095445            0.0     23.2379
# min    18.000000          1.000000   1.000000            1.0      1.0000
# 25%    29.750000          2.000000   2.000000            1.0     20.7500
# 50%    36.000000          7.000000   3.000000            1.0     40.5000
# 75%    43.000000         10.000000   4.000000            1.0     60.2500
# max    58.000000         29.000000   5.000000            1.0     80.0000
#
#         JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  80.000000      80.000000            80.00000          80.000000
# mean    1.962500   62541.375000             2.37500          15.275000
# std     1.084339   45599.715571             2.35665           4.003084
# ...

# %%
Null Hypothesis: for sample of 80 employees the mean YearsAtCompany is found to be 8

# %%
df.head(80).describe()
# Out:
#              Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  \
# count  80.000000         80.000000  80.000000           80.0     80.0000
# mean   36.475000          7.825000   2.800000            1.0     40.5000
# std     9.084658          6.929619   1.095445            0.0     23.2379
# min    18.000000          1.000000   1.000000            1.0      1.0000
# 25%    29.750000          2.000000   2.000000            1.0     20.7500
# 50%    36.000000          7.000000   3.000000            1.0     40.5000
# 75%    43.000000         10.000000   4.000000            1.0     60.2500
# max    58.000000         29.000000   5.000000            1.0     80.0000
#
#         JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  80.000000      80.000000            80.00000          80.000000
# mean    1.962500   62541.375000             2.37500          15.275000
# std     1.084339   45599.715571             2.35665           4.003084
# ...

# %%
Null Hypothesis: for sample of 80 employees the mean TotalWorkingYears is found to be 15
